# %%
#作業：寫一個函數，給定生日，print 年紀、生肖、星座、以及性格預測
#網路上應該有性格預測的參考資料。
#birthday 為一變數，年月日
#年紀與今年相減即得。
#由出生月日可得生肖與星座
#由生肖與星座可判斷個性。
#活用 dictionary, key 可為生消或星座，value 為性格預測
#給定 key 即得 value

# %%
def analysis(birth):
    day=int(birth[len(birth)-4:len(birth)])
    year=int(birth[:4])
    age=2019-year
    czs=['羊','猴','雞','狗','豬','鼠','牛','虎','兔','龍','蛇','馬']
    y=int(year%12)
    cnzodiac=czs[y+1]
    zozip={"水瓶座":[121,219],"雙魚座":[220,320],"牡羊座":[321,419],"金牛座":[420,520],"雙子座":[521,621],"巨蟹座":[622,722],"獅子座":[723,822],"處女座":[823,922],"天秤座":[923,1023],"天蠍座":[1024,1121],"射手座":[1122,1220],"摩羯座":[1221,1231]}
    key=list(zozip.keys())
    val=list(zozip.values())
    cnzodiacper=[["研究欲強，富有創造性。善良、寬容、順從。有耐心，不惹是非。適應環境快。"],["有進取心，喜歡競爭。多才多藝，多面手。略有虛榮心，生活浪漫，不受拘束"],
               ["精力充沛，善於言談。調查研究，講究效率。果斷、敏銳、好表現自己"],["意志堅定，忠實可靠。正義、公平、敏捷。聰明、有見識，有條理"],
               ["真摯、誠實、有同情心。精力旺盛，待人誠實。專心致志，凡事熱心"],["做事態度積極，勤奮努力，頭腦機智手腳靈巧。適應性強，善於結交各方面的朋友。多情善感，性格稍微內向"],
               ["勤奮努力，有強烈的進取心。忠厚老實，務實，責任心強，有耐力。有正義感，愛打抱不平"],["朝氣，有雄心壯志。敢想敢幹，勇於開拓。熱情大方，頑強自信，剛愎自用。"],
               ["溫柔、善良、樂觀，感情細膩。精明靈活，體諒他人。氣質高雅，思維細膩"],["勇往直前，有旺盛的進取心。專心致志，果斷肯干。孝順，慷慨，善於理財"],
               ["專心致志，認真負責。心靈手巧，思路敏捷。精力充沛，隨和開朗"],["精力旺盛，剛毅果斷。善惡分明，耿直熱情。能言善辯，不怕困難，勇往直前"]]
    zodiacper=[["個性喜歡在周遭觀察眾生百態，個性獨立且自主，富有創意與研究精神，但有時因想法標新立異、顛覆傳統，不容易與人群融合，會給人一種獨行俠或不合群的印象。"],["個性包容力強，富有直覺，悲天憫人，容易與人相處，但有時為求凡事融洽，作事缺乏原則，容易受騙上當，甚至有時會有自我催眠或自我欺騙的負面傾向。"],
             ["個性急切，做事講求效率，行動力十足，說做就做，創造性佳，但有時做事三分鐘熱度、缺乏耐性，且過於衝動，容易讓人產生欠缺思慮的不良印象。"],["個性趨於保守、務實且傳統。生活較重視物質層面，做事刻苦耐勞，耐力過人。不過有時會給人固執不知變通、做事刻板的感覺，甚至可能有物慾的傾象。"],
             ["個性具洞悉情勢、善於溝通、機智過人、應變能力強的特質。但雙子有時會過於善變，讓人捉摸不定的感覺，做事不夠專注，喜愛談論八卦，因此容易給人浮誇不實，甚至膚淺的印象。"],["個性偏好在固定範疇內行事以求得保護與安全感，常是家庭的守護者，個性較念舊敏銳，家庭意識深厚，若無法受到保護與慰藉時，容易產生排外性、防衛心、退縮閉塞的特質。"],
             ["個性較為自我，喜愛成為團體的中心或焦點，自尊心強烈，具有領導潛能與優越感。但倘若獅子座無法成為眾人的焦點，為了吸引它人目光，有時容易過度表現、行為誇張。"],["個性善於分析整理、識人之明、個性細膩，並追求完美，但當面對無法解構渾沌無規則可循的事物時，常顯現神經質與嘮叨不休的個性。"],
             ["個性對任何事物抱持著平衡的態度，性格著重公平客觀，對藝術有良好鑑賞力，但有時為取得平衡，容易表現出優柔寡斷的負面形象。"],["個性善於守密，沈穩，意志力堅強，深謀遠慮，但受冥王星的陰險特質影響，天蠍座也很容易多疑，善妒，佔有慾強，報復心重，甚至有時會有縱慾的傾向。"],
             ["個性喜愛思考探索與追尋哲理，個性樂觀，富理想，好自由，但有時常粗心大意，一副無所謂的樣子，令人感到沒有責任感，甚至有時會有過度樂觀的傾向。"],["個性具有堅毅的耐力，務實的態度，作事一步一腳印，個性嚴謹、守紀律，但受土星的影響，有時會表現出冷漠、憂鬱、悲觀、壓抑、欠缺浪漫與不易溝通的特質。"]]
    cnzod=dict(zip(czs,cnzodiacper))
    zod=dict(zip(key,zodiacper))
    if day<=120:
        zodiac=('摩羯座')
    for n in range(len(val)):
        if day>=val[n][0] and day<=val[n][1]:
            zodiac=(key[n])
    zper=(zod[zodiac])
    cnzper=(cnzod[cnzodiac])
    print('生日:',birth)
    print('年紀:',age)
    print('生肖:',cnzodiac)
    print('生肖性格:',cnzper)
    print('星座:',zodiac)
    print('星座性格:',zper)
birth='19950108'
analysis(birth)

#參考資料: https://www.twgreatdaily.com/cat70/node416164
#參考資料: https://astrodoor.cc/keyword/sign/pisces.jsp
# Out:
# 生日: 19950108
# 年紀: 24
# 生肖: 豬
# 生肖性格: ['真摯、誠實、有同情心。精力旺盛，待人誠實。專心致志，凡事熱心']
# 星座: 摩羯座
# 星座性格: ['個性具有堅毅的耐力，務實的態度，作事一步一腳印，個性嚴謹、守紀律，但受土星的影響，有時會表現出冷漠、憂鬱、悲觀、壓抑、欠缺浪漫與不易溝通的特質。']
